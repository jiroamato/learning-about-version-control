# %% [markdown]
# # Individual Assingment 1 Submission

# %% [markdown]
# Commit History Link:
#
# <https://github.com/jiroamato/learning-about-version-control/commits/main>

# %% [markdown]
# Resolving Merge Conflict:
#
# ![img](img/conflict_screenshot.png)

# %% [markdown]
# Working on a branch-pull-request workflow allows collaborators to separate changes to the repo while keeping the main branch thus preventing breaking anything on main. Also, by creating pull-requests, changes have to be reviewed so that the entire team can collectively look at potential changes. Directly committing creates an unstructured repository where changes are not coordinated within a team.
